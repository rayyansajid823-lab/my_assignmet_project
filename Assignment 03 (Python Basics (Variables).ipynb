# %% [markdown]
# ## Part -1 Python Basics (Variables)

# %% [markdown]
# 1. Print Your Name with your Father name and Date of birth using suitable escape sequence charactor

# %%
print("Name\t\t: Rayyan Sajid")
print("Father's Name\t: Sajid")
print("Date of Birth\t: 11 December 2008")
# Out:
# Name		: Rayyan Sajid
# Father's Name	: Sajid
# Date of Birth	: 11 December 2008

# %% [markdown]
# 2. Write your small bio using variables and print it using print function

# %%
# Variables

name = "Rayyan Sajid"
father_name = "Sajid"
date_of_birth = "11 December 2008"
city = "Karachi"
education = "Student"

# Print Bio

print("----- My Bio -----")
print("Name:", name)
print("Father's Name:", father_name)
print("Date of Birth:", date_of_birth)
print("City:", city)
print("Education:", education)
# Out:
# ----- My Bio -----
# Name: Rayyan Sajid
# Father's Name: Sajid
# Date of Birth: 11 December 2008
# City: Karachi
# Education: Student

# %% [markdown]
# 3. Write a program in which use all the operators we can use in Python

# %%
# Variables
a = 10
b = 5

# Arithmetic Operators
print("Addition:", a + b)
print("Subtraction:", a - b)
print("Multiplication:", a * b)
print("Division:", a / b)
print("Modulus:", a % b)
print("Exponent:", a ** b)
print("Floor Division:", a // b)

# Comparison Operators
print("a > b:", a > b)
print("a < b:", a < b)
print("a == b:", a == b)
print("a != b:", a != b)
print("a >= b:", a >= b)
print("a <= b:", a <= b)

# Logical Operators
print("a > 5 and b < 10:", a > 5 and b < 10)
print("a > 15 or b < 10:", a > 15 or b < 10)
print("not(a > b):", not(a > b))

# Assignment Operators
c = 10
c += 5
print("c += 5:", c)

c -= 3
print("c -= 3:", c)

# Membership Operators
list1 = [10, 20, 30]
print("10 in list1:", 10 in list1)
print("40 not in list1:", 40 not in list1)

# Identity Operators
x = [1, 2]
y = x
z = [1, 2]

print("x is y:", x is y)
print("x is z:", x is z)
print("x is not z:", x is not z)
# Out:
# Addition: 15
# Subtraction: 5
# Multiplication: 50
# Division: 2.0
# Modulus: 0
# Exponent: 100000
# Floor Division: 2
# a > b: True
# a < b: False
# a == b: False
# a != b: True
# a >= b: True
# a <= b: False
# a > 5 and b < 10: True
# a > 15 or b < 10: True
# not(a > b): False
# c += 5: 15
# c -= 3: 12
# 10 in list1: True
# 40 not in list1: True
# x is y: True
# x is z: False
# x is not z: True

# %% [markdown]
# 4. Completes the following steps of small task:
# Mention Marks of English , Islamiat and Maths out of 100 in 3 different variables
# Mention Variable of Total Marks and assign 300 to it
# Calculate Percentage

# %%
# Marks of Subjects
english = 85
islamiat = 90
maths = 95

# Total Marks
total_marks = 300

# Obtained Marks
obtained_marks = english + islamiat + maths

# Percentage
percentage = (obtained_marks / total_marks) * 100

# Print Result
print("English Marks:", english)
print("Islamiat Marks:", islamiat)
print("Maths Marks:", maths)
print("Total Marks:", total_marks)
print("Obtained Marks:", obtained_marks)
print("Percentage:", percentage, "%")
# Out:
# English Marks: 85
# Islamiat Marks: 90
# Maths Marks: 95
# Total Marks: 300
# Obtained Marks: 270
# Percentage: 90.0 %
